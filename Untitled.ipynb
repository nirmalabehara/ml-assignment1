# %%
import pandas as pd
heart_data = pd.read_csv('heart.csv')
o2_saturation = pd.read_csv('o2Saturation.csv')
heart_data.head(), o2_saturation.head()
# Out:
# (   age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
#  0   63    1   3     145   233    1        0       150     0      2.3    0
#  1   37    1   2     130   250    0        1       187     0      3.5    0
#  2   41    0   1     130   204    0        0       172     0      1.4    2
#  3   56    1   1     120   236    0        1       178     0      0.8    2
#  4   57    0   0     120   354    0        1       163     1      0.6    2
#
#     caa  thall  output
#  0    0      1       1
#  1    0      2       1
#  2    0      2       1
#  3    0      2       1
#  4    0      2       1  ,
#     98.6
#  0  98.6
#  1  98.6
#  2  98.6
#  3  98.1
#  4  97.5)

# %%
import pandas as pd

# Load the dataset
heart_data = pd.read_csv('heart.csv')
o2_saturation = pd.read_csv('o2Saturation.csv')

# Check for missing values
print(heart_data.isnull().sum())
print(o2_saturation.isnull().sum())
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64
# 98.6    0
# dtype: int64

# %%
heart_data_filled = heart_data.apply(lambda col: col.fillna(col.mode()[0]) if col.dtype == 'object' else col)
X = heart_data_cleaned.drop('output', axis=1)
y = heart_data_cleaned['output']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(X_train_scaled, y_train)
y_pred = model.predict(X_test_scaled)
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 80.22%

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
heart_data = pd.read_csv('heart.csv')
corr = heart_data.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %%
heart_data_cleaned = heart_data.dropna(axis=1)
o2_saturation_cleaned = o2_saturation.dropna(axis=1)
heart_data_cleaned['o2_saturation'] = o2_saturation_cleaned.iloc[:, 0]

# %%
heart_data_cleaned = pd.get_dummies(heart_data_cleaned, drop_first=True)

# %%
X = heart_data_cleaned.drop('output', axis=1)  # 'output' is the target column
y = heart_data_cleaned['output']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
model = RandomForestClassifier(random_state=42)
model.fit(X_train_scaled, y_train)
y_pred = model.predict(X_test_scaled)
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy * 100:.2f}%")
# Out:
# Model Accuracy: 82.42%

# %%
import joblib
joblib.dump(model, 'best_random_forest_model.pkl')
# Out:
# ['best_random_forest_model.pkl']
